# %%
# importing libraries
from bs4 import BeautifulSoup
import requests
# Out:
# /home/tushar/.local/lib/python3.5/site-packages/requests/__init__.py:91: RequestsDependencyWarning: urllib3 (1.25.3) or chardet (3.0.4) doesn't match a supported version!
#   RequestsDependencyWarning)

# %%
url="https://www.cartrade.com/buy-used-cars/mumbai/hyundai/elite-i20/3881734.html"

# %%
response=requests.get(url)
response.text
# Out:
# '  <!DOCTYPE html>\n  <html itemscope="" itemtype="https://schema.org/WebPage" lang="en" xmlns="http://www.w3.org/1999/xhtml">\n  <head prefix="og: https://ogp.me/ns# fb: https://ogp.me/ns/fb#">\n  <title>Used Hyundai Elite i20 1.2 Kappa Dual VTVT 5-Speed Manual Asta (O) (2016) in Mumbai - 3881734 | CarTrade</title>\n<meta name="description" content="Used Hyundai Elite i20 1.2 Kappa Dual VTVT 5-Speed Manual Asta (O) (2016) in Mumbai at CarTrade. (2016) Second Hand Hyundai Elite i20 for Sale in Mumbai at best price - 3881734." />\n<meta name="keywords" content="used hyundai elite i20 1.2 kappa dual vtvt 5-speed manual asta (o), second hand hyundai elite i20 1.2 kappa dual vtvt 5-speed manual asta (o), used hyundai elite i20 1.2 kappa dual vtvt 5-speed manual asta (o) form mumbai, second hand hyundai elite i20 1.2 kappa dual vtvt 5-speed manual asta (o) from mumbai, 2nd hand hyundai elite i20 1.2 kappa dual vtvt 5-speed manual asta (o) for mumbai" /> <meta http-equiv="Content-Type" content="text/html; charset=UTF-8" />\n<meta http-equiv="X-UA-Compatible" content="IE=edge" />\n<meta name="p:domain_verify" content="b18199effd18966f8371d5c6a89d679a"/>\n<meta name="verify-v1" content="t7AA94tCxcqsw3dg0cPP8L7cw4eP8I1z2fMJOF8x/es=" />\n<meta name="msvalidate.01" content="EFA688F23F4C9EACA6C8346AF349155D" />\n<meta name="validation_code" content="6a550d19bd46f2486bb008c4922cde7d" /> \n<meta property="fb:app_id" content="463383743692510"/>\n<link href="https://plus.google.com/+cartrade" rel="publisher" /> \n<!-- after fb Id -->\n<link rel="canonical" href="https://www.cartrade.com/buy-used-cars/mumbai/hyundai/elite-i20/3881734.html" />\n<link rel="alternate"  media="only screen and (max-width:640px)" href="https://m.cartrade.com/buy-used-cars/mumbai/hyundai/elite-i20/3881734.html" />\n<meta property="og:url" content="https://www.cartrade.com/buy-used-cars/mumbai/hyundai/elite-i20/3881734.html"/>\n<meta property="og:image" content="https://imguct3.aeplcdn.com/img/680x382/lis/201906/1711903_48949_1_1561711551994.jpeg?v=31"/>\n<meta property="og:title" content="Used Hyundai Elite i20 1.2 Kappa Dual VTVT 5-Speed Manual Asta (O) (2016) in Mumbai | CarTrade">\n<meta property="og:description" content="Used Hyundai Elite i20 1.2 Kappa Dual VTVT 5-Speed Manual Asta (O) (2016) in Mumbai at CarTrade. (2016) Second Hand Hyundai Elite i20 for Sale in Mumbai at best price.">\n<meta name="twitter:card" content="summary" />\n<meta name="twitter:site" content="@car_trade" />\n<meta name="twitter:creator" content="@car_trade" />\n<link rel="dns-prefetch" href="//jsct1.aeplcdn.com" >\n<link rel="dns-prefetch" href="//cssct1.aeplcdn.com" >\n<link rel="dns-prefetch" href="//imguct3.aeplcdn.com" >\n<link rel="dns-prefetch" href="//www.googleadservices.com" >\n<link rel="dns-prefetch" href="//www.googletagservices.com" >\n<link rel="dns-prefetch" href="//www.google-analytics.com" >\n<link rel="dns-prefetch" href="//media.go2speed.org" >\n<link rel="dns-prefetch" href="//cdn.perfdrive.com" >\n<link rel="dns-prefetch" href="//connect.facebook.com" >\n\n\n\t<script type="text/javascript" src="https://jsct1.aeplcdn.com/vehicle-description-layouts/v47/js/jquery-1.7.1.min.js-version60.js" ></script>\n\t<script type="text/javascript" src="https://jsct1.aeplcdn.com/vehicle-description-layouts/v47/js/common.js-version60.js"  async></script>\n\t<script type="text/javascript" src="https://jsct1.aeplcdn.com/vehicle-description-layouts/v47/js/cs-floater-form.js-version60.js"  async></script>\n   <link href="https://cssct1.aeplcdn.com/vehicle-description-layouts/v47/css/common.css-version60.css" rel="stylesheet" type="text/css">\n   <link href="https://cssct1.aeplcdn.com/vehicle-description-layouts/v47/css/cs-floater-form.css-version60.css" rel="stylesheet" type="text/css">\n    <link rel="icon" type="image/png" href="https://imgct2.aeplcdn.com/images4/favicon.png">\n    <link rel="apple-touch-icon" href="https://imgct2.aeplcdn.com/images4/apple-touch-icon.png"/>\n\n\n<scr ...

# %%
soup= BeautifulSoup(response.text,"html.parser")

# %%
for carname in soup.find_all("h1"):
    car=carname.text
    print(car)
    #print(type(car))
    brand=car.split(" ")
    
    brandName=str(brand[0])
    print(brandName)
    
    variant = ' '.join(brand[1:])
    print(variant)
    #print(type(variant))
# Out:
# Hyundai Elite i20 1.2 Kappa Dual VTVT 5-Speed Manual Asta (O) (2016)
# Hyundai
# Elite i20 1.2 Kappa Dual VTVT 5-Speed Manual Asta (O) (2016)

# %%
# this is for price
price1=[]

for div in soup.find_all("div",{"class":"wrapper v_content"}):
    #print(div)
    for div2 in div.find_all("div",{"class":"v_details"}):
        #print(div2)
        for div3 in div2.find_all("div",{"class":"pull-left"}):
            #print(div3)
            for span in div3.find_all("span"):
                  price1.append(span.text)
price2= price1[0:2]
price = ''.join(price2)
price
# Out:
# '₹ 6,75,000'

# %%
data=[]
for div in soup.find_all("div",{"class":"widgetBox"}):
    #print(div)
    for table in div.find_all("table",{"class":"v_table"}):
        #print(table)
        for tr in table.find_all("tr"):
            #print(tr.text)
            for td in tr.find_all("td"):
                #print(td.text)
                data.append(td.text)
    
# printing the elements in list
#print(data)
city=str(data[1])
fuel=str(data[3])
year=str(data[17])
mileage=str(data[5])
print(city,fuel,year,mileage)
# Out:
# Mumbai Petrol 2016 7,800 KM

# %%
Url=url.rpartition("buy")[0]
#Url
Site=Url.split(".")[1]
Site
# Out:
# 'cartrade'

# %%
import xlsxwriter

# %%
workbook=xlsxwriter.Workbook('Used_Car_Data_Alto.xlsx')
worksheet=workbook.add_worksheet()

# %%
row=2
column=3
#conten=["Column_Name","S.No","Car","Brand","Model","Variant","Fuel Type","Model Year","Mileage","Price","City","Site","Url"]
actualdata=["Description",2,car,brandName,variant,variant,fuel,year,mileage,price,city,Site,Url]

# %%
for items in actualdata:
    print(items)
    #worksheet.write(row,column,items)
    #row+=1
#workbook.close()
# Out:
# Description
# 2
# Hyundai Elite i20 1.2 Kappa Dual VTVT 5-Speed Manual Asta (O) (2016)
# Hyundai
# Elite i20 1.2 Kappa Dual VTVT 5-Speed Manual Asta (O) (2016)
# Elite i20 1.2 Kappa Dual VTVT 5-Speed Manual Asta (O) (2016)
# Petrol
# 2016
# 7,800 KM
# ₹ 6,75,000
# Mumbai
# cartrade
# https://www.cartrade.com/
